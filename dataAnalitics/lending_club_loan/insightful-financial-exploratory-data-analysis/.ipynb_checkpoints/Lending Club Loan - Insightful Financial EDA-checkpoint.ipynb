# %% [markdown]
# # Welcome to Lending Club Loan Dataset
# I will do some explorations through the Loan Club Data.
#
# NOTE: English is not my native language, so sorry about if you see any error

# %% [markdown]
# <b>About the dataset</b> <br>
# These files contain complete loan data for all loans issued through the 2007-2015, including the current loan status (Current, Late, Fully Paid, etc.) and latest payment information. The file containing loan data through the "present" contains complete loan data for all loans issued through the previous completed calendar quarter. Additional features include credit scores, number of finance inquiries, address including zip codes, and state, and collections among others. The file is a matrix of about 890 thousand observations and 75 variables. A data dictionary is provided in a separate file.

# %% [markdown]
# # Questions
# Some questions that I will try to answer:
# - Which type of data we are working?
# - We have missing values?
# - How many unique entries we have?
# - What's the distribution of Loan Status?
# - What's the distribution of Amount of loans?
# - What's the distribution of Interest Rate?
# - What's the % of Defaults in loans?
# - What's the most common grades?
# - What's the most common employer titles?
# - What's the most common Purpose that a client request a loan?
# - What's the different between Terms?
# - And a lot of other questions that will raise through the exploration;

# %% [markdown]
# <h2> Importing the Librarys </h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
from scipy import stats

#To plot figs on jupyter
# %matplotlib inline
# figure size in inches
rcParams['figure.figsize'] = 14,6

# %% [markdown]
# <h2> Importing our dataset</h2>

# %%
df_loan = pd.read_csv("template_bh/data/loan.csv",
                      low_memory=False)

# %% [markdown]
# ## Functions
# - To see all functions click in "code" button >

# %%
def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values

    for name in summary['Name'].value_counts().index:
        summary.loc[summary['Name'] == name, 'Entropy'] = round(stats.entropy(df[name].value_counts(normalize=True), base=2),2) 

    return summary

# %% [markdown]
# ## We will start looking all variables and some informations about them
# - I will divide 60 by 60 columns to a clear view of columns

# %% [markdown]
# ### Resuming table. 1st to 60th

# %%
resumetable(df_loan[:100000])[:60]
# Out:
# Dataset Shape: (100000, 145)
#                            Name   dtypes  Missing  Uniques  \
# 0                            id  float64   100000        0
# 1                     member_id  float64   100000        0
# 2                     loan_amnt    int64        0     1463
# 3                   funded_amnt    int64        0     1463
# 4               funded_amnt_inv  float64        0     1483
# 5                          term   object        0        2
# 6                      int_rate  float64        0       46
# 7                   installment  float64        0    10586
# 8                         grade   object        0        7
# 9                     sub_grade   object        0       35
# 10                    emp_title   object    16528    35595
# 11                   emp_length   object     9227       11
# 12               home_ownership   object        0        4
# 13                   annual_inc  float64        0     7969
# 14          verification_status   object        0        3
# 15                      issue_d   object        0        3
# 16                  loan_status   object        0        6
# 17                   pymnt_plan   object        0        2
# 18                          url  float64   100000        0
# 19                         desc   object   100000        0
# 20                      purpose   object        0       12
# 21                        title   object        0       12
# 22                     zip_code   object        0      875
# 23                   addr_state   object        0       50
# 24                          dti  float64      182     6108
# 25                  delinq_2yrs  float64        0       22
# 26             earliest_cr_line   object        0      638
# 27               inq_last_6mths  float64        0        6
# 28       mths_since_last_delinq  float64    56069      137
# 29       mths_since_last_record  float64    87899      114
# 30                     open_acc  float64        0       63
# 31                      pub_rec  float64        0        7
# 32                    revol_bal    int64        0    37570
# 33                   revol_util  float64      121     1069
# 34                    total_acc  float64        0      107
# 35          initial_list_status   object        0        2
# 36                    out_prncp  float64        0    25056
# 37                out_prncp_inv  float64        0    26554
# 38                  total_pymnt  float64        0    42474
# 39              total_pymnt_inv  float64        0    43650
# 40              total_rec_prncp  float64        0    23678
# 41                total_rec_int  float64        0    37470
# 42           total_rec_late_fee  float64        0      159
# 43                   recoveries  float64        0        1
# 44      collection_recovery_fee  float64        0        1
# 45                 last_pymnt_d   object      127        5
# 46              last_pymnt_amnt  float64        0    15819
# 47                 next_pymnt_d   object     2450        3
# 48           last_credit_pull_d   object        1        6
# 49   collections_12_mths_ex_med  float64        0        8
# 50  mths_since_last_major_derog  float64    77124      146
# 51                  policy_code    int64        0        1
# 52             application_type   object        0        2
# 53             annual_inc_joint  float64    87079     2772
# 54                    dti_joint  float64    87079     3365
# 55    verification_status_joint   object    88540        3
# 56               acc_now_delinq  float64        0        1
# 57                 tot_coll_amt  float64        0     3536
# 58                  tot_cur_bal  float64        0    82135
# 59                  open_acc_6m  float64        0       13
#
#            First Value        Second Value         Third Value  Entropy
# 0                  NaN                 NaN                 NaN     0.00
# 1                  NaN                 NaN                 NaN     0.00
# 2                 2500               30000                5000     6.00
# 3                 2500               30000                5000     6.00
# 4                 2500               30000                5000     6.18
# 5            36 months           60 months           36 months     0.90
# 6                13.56               18.94               17.97     4.96
# 7                84.92              777.23              180.69    11.17
# 8                    C                   D                   D     2.15
# 9                   C1                  D2                  D1     4.45
# 10                Chef         Postmaster       Administrative    13.11
# 11           10+ years           10+ years             6 years     3.03
# 12                RENT            MORTGAGE            MORTGAGE     1.40
# 13               55000               90000               59280     7.93
# 14        Not Verified     Source Verified     Source Verified     1.46
# 15            Dec-2018            Dec-2018            Dec-2018     1.50
# 16             Current             Current             Current     0.24
# 17                   n                   n                   n     0.00
# 18                 NaN                 NaN                 NaN     0.00
# 19                 NaN                 NaN                 NaN     0.00
# 20  debt_consolidation  debt_consolidation  debt_consolidation     1.88
# 21  Debt consolidation  Debt consolidation  Debt consolidation     1.88
# 22               109xx               713xx               490xx     8.92
# 23                  NY                  LA                  MI     4.87
# 24               18.24               26.52               10.51    11.90
# 25                   0                   0                   0     0.81
# 26            Apr-2001            Jun-1987            Apr-2011     8.41
# 27                   1                   0                   0     1.30
# 28                 NaN                  71                 NaN     6.30
# 29                  45                  75                 NaN     6.31
# 30                   9                  13                   8     4.45
# 31                   1                   1                   0     0.54
# 32                4341               12315                4599    14.79
# 33                10.3                24.2                19.1     9.86
# 34                  34                  44                  13     5.49
# 35                   w                   w                   w     0.49
# 36             2386.02             29387.8             4787.21    12.75
# 37             2386.02             29387.8             4787.21    12.86
# 38              167.02             1507.11              353.89    14.35
# 39              167.02             1507.11              353.89    14.42
# 40              113.98              612.25              212.79    12.83
# 41               53.04              894.86               141.1    14.22
# 42                   0                   0                   0     0.04
# 43                   0                   0                   0     0.00
# 44                   0                   0                   0     0.00
# 45            Feb-2019            Feb-2019            Feb-2019     0.25
# 46               84.92              777.23              180.69    11.56
# 47            Mar-2019            Mar-2019            Mar-2019     0.00
# 48            Feb-2019            Feb-2019            Feb-2019     0.21
# 49                   0                   0                   0     0.13
# 50                 NaN                 NaN                 NaN     6.37
# 51                   1                   1                   1     0.00
# 52          Individual          Individual          Individual     0.56
# 53                 NaN                 NaN                 NaN     9.04
# 54                 NaN                 NaN                 NaN    11.44
# 55                 NaN                 NaN                 NaN     1.54
# 56                   0                   0                   0     0.00
# 57                   0                1208                   0     2.08
# 58               16901              321915              110299    16.22
# 59                   2                   4                   0     1.92

# %% [markdown]
# ### Resuming table. 61th to 120th

# %%
resumetable(df_loan[:100000])[60:112]
# Out:
# Dataset Shape: (100000, 145)
#                                Name   dtypes  Missing  Uniques First Value  \
# 60                      open_act_il  float64        0       42           2
# 61                      open_il_12m  float64        0        7           1
# 62                      open_il_24m  float64        0       17           2
# 63               mths_since_rcnt_il  float64     3448      263           2
# 64                     total_bal_il  float64        0    55389       12560
# 65                          il_util  float64    15652      194          69
# 66                      open_rv_12m  float64        0       22           2
# 67                      open_rv_24m  float64        0       32           7
# 68                       max_bal_bc  float64        0    19527        2137
# 69                         all_util  float64       30      148          28
# 70                 total_rev_hi_lim  float64        0     3633       42000
# 71                           inq_fi  float64        0       24           1
# 72                      total_cu_tl  float64        0       43          11
# 73                     inq_last_12m  float64        0       34           2
# 74             acc_open_past_24mths  float64        0       37           9
# 75                      avg_cur_bal  float64        9    35291        1878
# 76                   bc_open_to_buy  float64     1309    36939       34360
# 77                          bc_util  float64     1357     1107         5.9
# 78         chargeoff_within_12_mths  float64        0        7           0
# 79                      delinq_amnt  float64        0       26           0
# 80               mo_sin_old_il_acct  float64     3448      440         140
# 81             mo_sin_old_rev_tl_op  float64        0      669         212
# 82            mo_sin_rcnt_rev_tl_op  float64        0      226           1
# 83                   mo_sin_rcnt_tl  float64        0      150           1
# 84                         mort_acc  float64        0       23           0
# 85             mths_since_recent_bc  float64     1225      367           1
# 86         mths_since_recent_bc_dlq  float64    80195      141         NaN
# 87            mths_since_recent_inq  float64    12234       26           2
# 88   mths_since_recent_revol_delinq  float64    71168      145         NaN
# 89            num_accts_ever_120_pd  float64        0       26           0
# 90                   num_actv_bc_tl  float64        0       28           2
# 91                  num_actv_rev_tl  float64        0       39           5
# 92                      num_bc_sats  float64        0       40           3
# 93                        num_bc_tl  float64        0       52           3
# 94                        num_il_tl  float64        0       80          16
# 95                    num_op_rev_tl  float64        0       56           7
# 96                    num_rev_accts  float64        0       81          18
# 97              num_rev_tl_bal_gt_0  float64        0       38           5
# 98                         num_sats  float64        0       63           9
# 99                 num_tl_120dpd_2m  float64     2486        1           0
# 100                    num_tl_30dpd  float64        0        1           0
# 101              num_tl_90g_dpd_24m  float64        0       21           0
# 102              num_tl_op_past_12m  float64        0       23           3
# 103                  pct_tl_nvr_dlq  float64        0      462         100
# 104                percent_bc_gt_75  float64     1310      152           0
# 105            pub_rec_bankruptcies  float64        0        7           1
# 106                       tax_liens  float64        0        1           0
# 107                 tot_hi_cred_lim  float64        0    76916       60124
# 108               total_bal_ex_mort  float64        0    66496       16901
# 109                  total_bc_limit  float64        0     2516       36500
# 110      total_il_high_credit_limit  float64        0    55744       18124
# 111                 revol_bal_joint  float64    87079    11835         NaN
#
#     Second Value Third Value  Entropy
# 60             4           1     3.00
# 61             2           0     1.64
# 62             3           2     2.41
# 63             3          14     5.65
# 64         87153        7150    14.23
# 65            88          72     6.54
# 66             4           0     2.17
# 67             5           2     2.99
# 68           998           0    13.52
# 69            57          35     6.40
# 70         50800       24100     9.99
# 71             2           1     2.11
# 72            15           5     2.35
# 73             2           0     2.68
# 74            10           4     3.51
# 75         24763       18383    14.56
# 76         13761       13800    14.62
# 77           8.3           0     9.92
# 78             0           0     0.06
# 79             0           0     0.00
# 80           163          87     7.72
# 81           378          92     8.49
# 82             4          15     5.35
# 83             3          14     4.50
# 84             3           2     2.27
# 85             4          77     6.07
# 86           NaN         NaN     6.38
# 87             4          14     4.34
# 88           NaN         NaN     6.34
# 89             0           0     1.18
# 90             2           0     3.13
# 91             4           3     3.60
# 92             4           3     3.49
# 93             9           3     3.97
# 94            27           4     4.49
# 95             8           6     4.11
# 96            14           7     4.76
# 97             4           3     3.58
# 98            13           8     4.44
# 99             0           0     0.00
# 100            0           0     0.00
# 101            0           0     0.30
# 102            6           0     2.69
# 103           95         100     4.03
# 104            0           0     3.58
# 105            1           0     0.54
# 106            0           0     0.00
# 107       372872      136927    15.81
# 108        99468       11749    15.84
# 109        15000       13800     9.45
# 110        94072       10000    13.76
# 111          NaN         NaN    13.48

# %% [markdown]
# ### Resuming table. 120th to 148th

# %%
resumetable(df_loan[:100000])[112:]
# Out:
# Dataset Shape: (100000, 145)
#                                            Name   dtypes  Missing  Uniques  \
# 112                    sec_app_earliest_cr_line   object    87079      557
# 113                      sec_app_inq_last_6mths  float64    87079        7
# 114                            sec_app_mort_acc  float64    87079       15
# 115                            sec_app_open_acc  float64    87079       52
# 116                          sec_app_revol_util  float64    87282     1054
# 117                         sec_app_open_act_il  float64    87079       32
# 118                       sec_app_num_rev_accts  float64    87079       66
# 119            sec_app_chargeoff_within_12_mths  float64    87079       12
# 120          sec_app_collections_12_mths_ex_med  float64    87079       11
# 121         sec_app_mths_since_last_major_derog  float64    95994      113
# 122                               hardship_flag   object        0        2
# 123                               hardship_type   object    99999        1
# 124                             hardship_reason   object    99999        1
# 125                             hardship_status   object    99999        1
# 126                               deferral_term  float64    99999        1
# 127                             hardship_amount  float64    99999        1
# 128                         hardship_start_date   object    99999        1
# 129                           hardship_end_date   object    99999        1
# 130                     payment_plan_start_date   object    99999        1
# 131                             hardship_length  float64    99999        1
# 132                                hardship_dpd  float64    99999        1
# 133                        hardship_loan_status   object    99999        1
# 134  orig_projected_additional_accrued_interest  float64    99999        1
# 135              hardship_payoff_balance_amount  float64    99999        1
# 136                hardship_last_payment_amount  float64    99999        1
# 137                         disbursement_method   object        0        2
# 138                        debt_settlement_flag   object        0        2
# 139                   debt_settlement_flag_date   object    99999        1
# 140                           settlement_status   object    99999        1
# 141                             settlement_date   object    99999        1
# 142                           settlement_amount  float64    99999        1
# 143                       settlement_percentage  float64    99999        1
# 144                             settlement_term  float64    99999        1
#
#     First Value Second Value Third Value  Entropy
# 112         NaN          NaN         NaN     8.38
# 113         NaN          NaN         NaN     1.51
# 114         NaN          NaN         NaN     2.47
# 115         NaN          NaN         NaN     4.62
# 116         NaN          NaN         NaN     9.83
# 117         NaN          NaN         NaN     3.16
# 118         NaN          NaN         NaN     4.85
# 119         NaN          NaN         NaN     0.19
# 120         NaN          NaN         NaN     0.32
# 121         NaN          NaN         NaN     6.39
# 122           N            N           N     0.00
# 123         NaN          NaN         NaN     0.00
# 124         NaN          NaN         NaN     0.00
# 125         NaN          NaN         NaN     0.00
# 126         NaN          NaN         NaN     0.00
# 127         NaN          NaN         NaN     0.00
# 128         NaN          NaN         NaN     0.00
# 129         NaN          NaN         NaN     0.00
# 130         NaN          NaN         NaN     0.00
# 131         NaN          NaN         NaN     0.00
# 132         NaN          NaN         NaN     0.00
# 133         NaN          NaN         NaN     0.00
# 134         NaN          NaN         NaN     0.00
# 135         NaN          NaN         NaN     0.00
# 136         NaN          NaN         NaN     0.00
# 137        Cash         Cash        Cash     0.71
# 138           N            N           N     0.00
# 139         NaN          NaN         NaN     0.00
# 140         NaN          NaN         NaN     0.00
# 141         NaN          NaN         NaN     0.00
# 142         NaN          NaN         NaN     0.00
# 143         NaN          NaN         NaN     0.00
# 144         NaN          NaN         NaN     0.00

# %% [markdown]
# ## Our Target would be the Purpose values.
# - Let's understand which type of category values we have
# - We need To select loans that are fully paid and that are not fully paid, removing current loans

# %%
total = len(df_loan)

plt.figure(figsize = (14,6))

g = sns.countplot(x="loan_status", data=df_loan, 
                  color='blue')
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_xlabel("Loan Status Categories", fontsize=12)
g.set_ylabel("Count", fontsize=15)
g.set_title("Loan Status Types Distribution", fontsize=20)
sizes=[]
for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g.set_ylim(0, max(sizes) * 1.10)

plt.show()

# %% [markdown]
# Cool! The values of interest are Fully Paid, Charged Off and Default values;

# %%
df_loan = df_loan.loc[df_loan['loan_status'].isin(['Fully Paid', 'Charged Off', 'Default'])]

# %% [markdown]
# # Purpose
# - Purpose - A category provided by the borrower for the loan request.
# - As it a categorical feature that says what's the purpose to the loan, would be interesting to start by Purpose.

# %%
plt.figure(figsize=(14,6))

g = sns.countplot(x='purpose', data=df_loan, 
                  color='blue')
g.set_title("Client Purposes for Loan Credit", fontsize=22)
g.set_xlabel("Purpose Titles", fontsize=18)
g.set_ylabel('Count', fontsize=18)

sizes=[]

for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=14) 
    
g.set_ylim(0, max(sizes) * 1.10)
g.set_xticklabels(g.get_xticklabels(),
                  rotation=45)

plt.show()

# %% [markdown]
# Cool! The top 3 purposes are:
# - 56.5% of the Loans are to Debt Consolidation
# - 22.87% are to pay Credit Card
# - 6.67% to Home Improvement
# - and many others purposes that sums 13.94%

# %% [markdown]
# # LOAN AMOUNT and INTEREST RATE Distributions
# <b>Loan Amount</b> - <i>The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.</i><br>
# <b>intRate </b>- <i>Interest Rate on the loan</i>

# %%
df_loan['int_round'] = df_loan['int_rate'].round(0).astype(int)

#I will start looking the loan_amnt column
plt.figure(figsize=(14,10))

# Loan Amt plot
plt.subplot(211)
g = sns.distplot(df_loan["loan_amnt"])
g.set_xlabel("Loan Amount Value", fontsize=16)
g.set_ylabel("Frequency", fontsize=16)
g.set_title("Loan Amount Distribuition", fontsize=20)

## Interest plot
plt.subplot(212)
g1 = sns.countplot(x="int_round", data=df_loan, 
                  color='blue')
g1.set_xlabel("Loan Interest Rate", fontsize=16)
g1.set_ylabel("Count", fontsize=16)
g1.set_title("Interest Rate Distribuition", fontsize=20)
sizes=[] # Get highest values in y
for p in g1.patches:
    height = p.get_height()
    sizes.append(height)
    g1.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g1.set_ylim(0, max(sizes) * 1.10) # set y limit based on highest heights

plt.subplots_adjust(hspace = 0.4,top = 0.9)

plt.show()

# %% [markdown]
# Nice ! <br>
# We can note that a big part of the loans are values until USD 10,000 ( we will explore the quantiles and outliers too) <br>
# Also, many part of all loans have interest between 7% and 14%;  <br>
# In <b>Interest Rate:</b> The most common is 14%, followed by 13% and 11%.

# %% [markdown]
# # Loan Status
# Understanding the default

# %%
df_loan.loc[df_loan.loan_status == \
            'Does not meet the credit policy. Status:Fully Paid', 'loan_status'] = 'NMCP Fully Paid'
df_loan.loc[df_loan.loan_status == \
            'Does not meet the credit policy. Status:Charged Off', 'loan_status'] = 'NMCP Charged Off'

# %% [markdown]
# <h2>Loan Status Distribuition</h2>

# %%
plt.figure(figsize = (12,16))

plt.subplot(311)
g = sns.countplot(x="loan_status", data=df_loan, 
                  color='blue')
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_xlabel("Loan Status Categories", fontsize=12)
g.set_ylabel("Count", fontsize=15)
g.set_title("Loan Status Types Distribution", fontsize=20)
sizes=[]
for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g.set_ylim(0, max(sizes) * 1.10)

plt.subplot(312)
g1 = sns.boxplot(x="loan_status", y="int_round", data=df_loan, 
                 color='blue')
g1.set_xticklabels(g1.get_xticklabels(),rotation=45)
g1.set_xlabel("Loan Status Categories", fontsize=12)
g1.set_ylabel("Interest Rate Distribution", fontsize=15)
g1.set_title("Loan Status by Interest Rate", fontsize=20)

plt.subplot(313)
g2 = sns.boxplot(x="loan_status", y="loan_amnt", data=df_loan, 
                 color='blue')
g2.set_xticklabels(g2.get_xticklabels(),rotation=45)
g2.set_xlabel("Loan Status Categories", fontsize=15)
g2.set_ylabel("Loan Amount Distribution", fontsize=15)
g2.set_title("Loan Status by Loan Amount", fontsize=20)

plt.subplots_adjust(hspace = 0.7,top = 0.9)

plt.show()

# %% [markdown]
# Cool!
#
#
# We can see that People that Not meet the credit policy has a lowest values in amount distribution.

# %% [markdown]
# <h2>ISSUE_D</h2>
#
# Going depth in the default exploration to see the amount and counting though the <b>ISSUE_D </b>,<br>
# that is: <i><b> The month which the loan was funded</b></i>

# %%
df_loan['issue_month'], df_loan['issue_year'] = df_loan['issue_d'].str.split('-', 1).str
# Out:
# <ipython-input-14-577d55d56899>:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df_loan['issue_month'], df_loan['issue_year'] = df_loan['issue_d'].str.split('-', 1).str

# %%
months_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", 
                "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
df_loan['issue_month'] = pd.Categorical(df_loan['issue_month'],
                                        categories=months_order, 
                                        ordered=True)
#Issue_d x loan_amount
plt.figure(figsize = (15,16))

plt.subplot(311)
g = sns.countplot(x='issue_month', hue='issue_year', 
                  data=df_loan[df_loan['issue_year'].astype(int) >= 2012])
#g.set_xticklabels(g.get_xticklabels(),rotation=90)
g.set_xlabel("Months of Year", fontsize=15)
g.set_ylabel("Count Loans", fontsize=15)
g.legend(loc='best')
g.set_title("Loan Amount by Months", fontsize=20)

plt.subplot(312)
#Looking the count of defaults though the issue_d that is The month which the loan was funded
g1 = sns.countplot(x='issue_year', hue='term', 
                   data=df_loan)
g1.set_xticklabels(g1.get_xticklabels(),rotation=90)
g1.set_xlabel("Years", fontsize=15)
g1.set_ylabel("Count Loans", fontsize=15)
g1.set_title("Total Loans by Years - With Term requested", fontsize=20)
sizes=[]
for p in g1.patches:
    height = p.get_height()
    sizes.append(height)
    g1.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g1.set_ylim(0, max(sizes) * 1.10)

plt.subplot(313)
#Looking the count of defaults though the issue_d that is The month which the loan was funded
g2 = sns.countplot(x='issue_year', data=df_loan.loc[(df_loan['loan_status'] == 'Charged Off') | 
                                                   (df_loan['loan_status'] == 'NMCP Charged Off') |
                                                   (df_loan['loan_status'] == 'Default')],
                  hue='term',)
g2.set_xticklabels(g.get_xticklabels(),rotation=90)
g2.set_xlabel("Dates", fontsize=15)
g2.set_ylabel("Count", fontsize=15)
g2.set_title("Analysing Charge Off and Default by Years", fontsize=20)
sizes=[]
for p in g2.patches:
    height = p.get_height()
    sizes.append(height)
    g2.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g2.set_ylim(0, max(sizes) * 1.10)

plt.subplots_adjust(hspace = 0.3,top = 0.9)

plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# Cool! We can note that the peak(60k) of loans was in March 2016; <br>
# The data is more consistent after 2012 ~ 2013... And it's seem to a linear growth by the years

# %% [markdown]
# # Crosstab - Purpose by Loan Status

# %%
#Exploring the loan_status x purpose
purp_loan= ['purpose', 'loan_status']
cm = sns.light_palette("green", as_cmap=True)
(round(pd.crosstab(df_loan[purp_loan[0]], df_loan[purp_loan[1]], 
                   normalize='columns') * 100,2)).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row0_col0 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row0_col1 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row0_col2 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row1_col0 {
#             background-color:  #a0d9a0;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row1_col1 {
#             background-color:  #b6e5b6;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row1_col2 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row2_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row4_col0 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row4_col1 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row4_col2 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row5_col0 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row5_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row6_col0 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row6_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row6_col2 {
#             background-color:  #ddfbdd;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row7_col0 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row7_col1 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row7_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row8_col0 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row8_col1 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row8_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row9_col0 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row9_col1 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row9_col2 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row10_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row10_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row10_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row11_col0 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row11_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row11_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row12_col0 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row12_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row12_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row13_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row13_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb4_ac3e_11ea_b500_0005165a0b35row13_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35" ><thead>    <tr>        <th class="index_name level0" >loan_status</th>        <th class="col_heading level0 col0" >Charged Off</th>        <th class="col_heading level0 col1" >Default</th>        <th class="col_heading level0 col2" >Fully Paid</th>    </tr>    <tr>        <th class="index_name level0" >purpose</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35level0_row0" class="row_heading level0 row0" >car</th>
#                         <td id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35row0_col0" class="data row0 col0" >0.790000</td>
#                         <td id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35row0_col1" class="data row0 col1" >3.230000</td>
#                         <td id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35row0_col2" class="data row0 col2" >1.160000</td>
#             </tr>
#             <tr>
#                         <th id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35level0_row1" class="row_heading level0 row1" >credit_card</th>
#                         <td id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35row1_col0" class="data row1 col0" >18.590000</td>
#                         <td id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35row1_col1" class="data row1 col1" >12.900000</td>
#                         <td id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35row1_col2" class="data row1 col2" >22.750000</td>
#             </tr>
#             <tr>
#                         <th id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35level0_row2" class="row_heading level0 row2" >debt_consolidation</th>
#                         <td id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35row2_col0" class="data row2 col0" >61.550000</td>
#                         <td id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35row2_col1" class="data row2 col1" >61.290000</td>
#                         <td id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35row2_col2" class="data row2 col2" >57.250000</td>
#             </tr>
#             <tr>
#                         <th id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35level0_row3" class="row_heading level0 row3" >educational</th>
#                         <td id="T_006c9eb4_ac3e_11ea_b500_0005165a0b35row3_col0" class="data row3 col0" >0.020000</td>
#                         <t

# %% [markdown]
# # Crosstab - Loan Status by Grade

# %%
loan_grade = ['loan_status', 'grade']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_loan[loan_grade[0]], df_loan[loan_grade[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col0 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col1 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col2 {
#             background-color:  #a3daa3;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col3 {
#             background-color:  #81c781;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col4 {
#             background-color:  #55af55;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col5 {
#             background-color:  #279527;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }</style><table id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35" ><thead>    <tr>        <th class="index_name level0" >grade</th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>        <th class="col_heading level0 col6" >G</th>    </tr>    <tr>        <th class="index_name level0" >loan_status</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35level0_row0" class="row_heading level0 row0" >Charged Off</th>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col0" class="data row0 col0" >13766</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col1" class="data row0 col1" >51077</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col2" class="data row0 col2" >83262</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col3" class="data row0 col3" >59441</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col4" class="data row0 col4" >35364</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col5" class="data row0 col5" >14263</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row0_col6" class="data row0 col6" >4482</td>
#             </tr>
#             <tr>
#                         <th id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35level0_row1" class="row_heading level0 row1" >Default</th>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col1" class="data row1 col1" >6</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col2" class="data row1 col2" >9</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col3" class="data row1 col3" >8</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col4" class="data row1 col4" >4</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col5" class="data row1 col5" >2</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row1_col6" class="data row1 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35level0_row2" class="row_heading level0 row2" >Fully Paid</th>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col0" class="data row2 col0" >212477</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col1" class="data row2 col1" >329075</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col2" class="data row2 col2" >286666</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col3" class="data row2 col3" >135839</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col4" class="data row2 col4" >56206</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col5" class="data row2 col5" >17220</td>
#                         <td id="T_006c9eb5_ac3e_11ea_b500_0005165a0b35row2_col6" class="data row2 col6" >4469</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Interest Rate by Grade and Loan_status
# Is the

# %%
loan_grade = ['loan_status', 'grade']
cm = sns.light_palette("green", as_cmap=True)
round(pd.crosstab(df_loan[loan_grade[0]], df_loan[loan_grade[1]], 
            values=df_loan['int_rate'], aggfunc='mean'),2).fillna(0).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col1 {
#             background-color:  #118911;
#             color:  #f1f1f1;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col2 {
#             background-color:  #83c983;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col3 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col4 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col5 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col0 {
#             background-color:  #b3e3b3;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col6 {
#             background-color:  #048204;
#             color:  #f1f1f1;
#         }</style><table id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35" ><thead>    <tr>        <th class="index_name level0" >grade</th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>        <th class="col_heading level0 col6" >G</th>    </tr>    <tr>        <th class="index_name level0" >loan_status</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35level0_row0" class="row_heading level0 row0" >Charged Off</th>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col0" class="data row0 col0" >7.390000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col1" class="data row0 col1" >10.790000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col2" class="data row0 col2" >14.070000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col3" class="data row0 col3" >17.760000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col4" class="data row0 col4" >21.160000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col5" class="data row0 col5" >25.050000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row0_col6" class="data row0 col6" >27.910000</td>
#             </tr>
#             <tr>
#                         <th id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35level0_row1" class="row_heading level0 row1" >Default</th>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col0" class="data row1 col0" >7.030000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col1" class="data row1 col1" >10.800000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col2" class="data row1 col2" >14.150000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col3" class="data row1 col3" >18.730000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col4" class="data row1 col4" >25.530000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col5" class="data row1 col5" >30.220000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row1_col6" class="data row1 col6" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35level0_row2" class="row_heading level0 row2" >Fully Paid</th>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col0" class="data row2 col0" >7.110000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col1" class="data row2 col1" >10.670000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col2" class="data row2 col2" >14.010000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col3" class="data row2 col3" >17.670000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col4" class="data row2 col4" >21.070000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col5" class="data row2 col5" >24.770000</td>
#                         <td id="T_006c9eb6_ac3e_11ea_b500_0005165a0b35row2_col6" class="data row2 col6" >27.470000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Wow! It's very meaningful.
# It's clear note the differences between the interest in Grades.

# %% [markdown]
# # Verification Status
# - Indicates if the co-borrowers' joint income was verified by LC, not verified, or if the income source was verified

# %%
plt.figure(figsize = (13,6))

g = sns.countplot(x="verification_status", data=df_loan, 
                  color='blue')
g.set_xlabel("Loan Status Categories", fontsize=15)
g.set_ylabel("Count", fontsize=15)
g.set_title("Loan Status Types Distribution", fontsize=20)
sizes=[]
for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=14) 
g.set_ylim(0, max(sizes) * 1.10)

plt.show()

# %% [markdown]
# Cool! Only 32.95% of the loans are not verified; <br>
# Let's see the distribution of Verification Status by Loan Status

# %% [markdown]
# ## Verification Status by Loan Status

# %%
#Looking the 'verification_status' column that is the Indicates 
#if the co-borrowers' joint income was verified by LC, not verified, or if the income source was verified
loan_verification = ['loan_status', 'verification_status']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_loan[loan_verification[0]], df_loan[loan_verification[1]], 
            normalize='index').style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_006c9eb7_ac3e_11ea_b500_0005165a0b35row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb7_ac3e_11ea_b500_0005165a0b35row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb7_ac3e_11ea_b500_0005165a0b35row0_col2 {
#             background-color:  #57b057;
#             color:  #000000;
#         }    #T_006c9eb7_ac3e_11ea_b500_0005165a0b35row1_col0 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_006c9eb7_ac3e_11ea_b500_0005165a0b35row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_006c9eb7_ac3e_11ea_b500_0005165a0b35row1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb7_ac3e_11ea_b500_0005165a0b35row2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_006c9eb7_ac3e_11ea_b500_0005165a0b35row2_col1 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_006c9eb7_ac3e_11ea_b500_0005165a0b35row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35" ><thead>    <tr>        <th class="index_name level0" >verification_status</th>        <th class="col_heading level0 col0" >Not Verified</th>        <th class="col_heading level0 col1" >Source Verified</th>        <th class="col_heading level0 col2" >Verified</th>    </tr>    <tr>        <th class="index_name level0" >loan_status</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35level0_row0" class="row_heading level0 row0" >Charged Off</th>
#                         <td id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35row0_col0" class="data row0 col0" >0.220512</td>
#                         <td id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35row0_col1" class="data row0 col1" >0.406554</td>
#                         <td id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35row0_col2" class="data row0 col2" >0.372934</td>
#             </tr>
#             <tr>
#                         <th id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35level0_row1" class="row_heading level0 row1" >Default</th>
#                         <td id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35row1_col0" class="data row1 col0" >0.225806</td>
#                         <td id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35row1_col1" class="data row1 col1" >0.354839</td>
#                         <td id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35row1_col2" class="data row1 col2" >0.419355</td>
#             </tr>
#             <tr>
#                         <th id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35level0_row2" class="row_heading level0 row2" >Fully Paid</th>
#                         <td id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35row2_col0" class="data row2 col0" >0.321039</td>
#                         <td id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35row2_col1" class="data row2 col1" >0.381351</td>
#                         <td id="T_006c9eb7_ac3e_11ea_b500_0005165a0b35row2_col2" class="data row2 col2" >0.297611</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Cool! We found a interesting pattern. <br>
# Loan Status NMCP(Not Meet Credit Politic) have the most part of loans as "Not verified" with a highest mean in comparison with other categorys

# %% [markdown]
# <h2>INSTALLMENT Column </h2> <br>
# <i>The monthly payment owed by the borrower if the loan originates.</i>

# %%
plt.figure(figsize=(12,5))

sns.distplot(df_loan['installment'])
plt.title("Installment Distribution", fontsize=20)
plt.xlabel("Installment Range", fontsize=17)
plt.ylabel("Density", fontsize=17)

plt.show()

# %% [markdown]
# Nice. We can see that the peak of our distribution is ~300 USD monthly.
#
# With this information, we can investigate the difference between emp_title or regions, to find some interesting patterns of values

# %% [markdown]
# # Installment by Loan Status

# %%
plt.figure(figsize = (14,12))

plt.subplot(211)
g = sns.violinplot(x='loan_status', y="installment",
                   data=df_loan, color='blue')
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_xlabel("Loan Status", fontsize=17)
g.set_ylabel("Installment", fontsize=17)
g.set_title("Installment Distribution by Loan Status", fontsize=20)

plt.subplot(212)
g1 = sns.violinplot(x='loan_status', y="total_acc",
                   data=df_loan, color='blue')
g1.set_xticklabels(g.get_xticklabels(),rotation=45)
g1.set_xlabel("Loan Status", fontsize=17)
g1.set_ylabel("Total Account lines", fontsize=17)
g1.set_title("Total Account Lines Distribution by Loan Status", fontsize=20)

plt.subplots_adjust(hspace = 0.5,top = 0.9)

plt.show()

# %% [markdown]
# # Crosstab - Loan Status by Application Type

# %%
#Exploring the loan_status x Application_type
loan_application = ['loan_status', 'application_type']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_loan[loan_application[0]], df_loan[loan_application[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_06c62186_ac3e_11ea_b500_0005165a0b35row0_col0 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_06c62186_ac3e_11ea_b500_0005165a0b35row0_col1 {
#             background-color:  #9bd69b;
#             color:  #000000;
#         }    #T_06c62186_ac3e_11ea_b500_0005165a0b35row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_06c62186_ac3e_11ea_b500_0005165a0b35row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_06c62186_ac3e_11ea_b500_0005165a0b35row2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_06c62186_ac3e_11ea_b500_0005165a0b35row2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }</style><table id="T_06c62186_ac3e_11ea_b500_0005165a0b35" ><thead>    <tr>        <th class="index_name level0" >application_type</th>        <th class="col_heading level0 col0" >Individual</th>        <th class="col_heading level0 col1" >Joint App</th>    </tr>    <tr>        <th class="index_name level0" >loan_status</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_06c62186_ac3e_11ea_b500_0005165a0b35level0_row0" class="row_heading level0 row0" >Charged Off</th>
#                         <td id="T_06c62186_ac3e_11ea_b500_0005165a0b35row0_col0" class="data row0 col0" >255926</td>
#                         <td id="T_06c62186_ac3e_11ea_b500_0005165a0b35row0_col1" class="data row0 col1" >5729</td>
#             </tr>
#             <tr>
#                         <th id="T_06c62186_ac3e_11ea_b500_0005165a0b35level0_row1" class="row_heading level0 row1" >Default</th>
#                         <td id="T_06c62186_ac3e_11ea_b500_0005165a0b35row1_col0" class="data row1 col0" >24</td>
#                         <td id="T_06c62186_ac3e_11ea_b500_0005165a0b35row1_col1" class="data row1 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_06c62186_ac3e_11ea_b500_0005165a0b35level0_row2" class="row_heading level0 row2" >Fully Paid</th>
#                         <td id="T_06c62186_ac3e_11ea_b500_0005165a0b35row2_col0" class="data row2 col0" >1024444</td>
#                         <td id="T_06c62186_ac3e_11ea_b500_0005165a0b35row2_col1" class="data row2 col1" >17508</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <h2>Distribuition of Application_tye thought the Loan Amount and Interest Rate</h2>

# %%
plt.figure(figsize = (12,14))
#The amount and int rate x application_type 
plt.subplot(211)
g = sns.violinplot(x="application_type", y="loan_amnt",data=df_loan, 
            palette="hls")
g.set_title("Application Type - Loan Amount", fontsize=20)
g.set_xlabel("", fontsize=15)
g.set_ylabel("Loan Amount", fontsize=15)

plt.subplot(212)
g1 = sns.violinplot(x="application_type", y="int_rate",data=df_loan,
               palette="hls")
g1.set_title("Application Type - Interest Rate", fontsize=20)
g1.set_xlabel("", fontsize=15)
g1.set_ylabel("Int Rate", fontsize=15)

plt.subplots_adjust(wspace = 0.4, hspace = 0.4,top = 0.9)

plt.show()

# %% [markdown]
# <h2>Looking the Home Ownership by Loan_Amount</h2>

# %%
plt.figure(figsize = (14,12))

plt.subplot(211)
g = sns.violinplot(x="home_ownership",y="loan_amnt",data=df_loan,
               kind="violin",
               split=True,palette="hls",
               hue="application_type")
g.set_title("Homer Ownership - Loan Amount Distribuition", fontsize=20)
g.set_xlabel("", fontsize=15)
g.set_ylabel("Loan Amount", fontsize=15)

plt.subplot(212)
g1 = sns.violinplot(x="home_ownership",y="int_rate",data=df_loan,
               kind="violin",
               split=True,palette="hls",
               hue="application_type")
g1.set_title("Homer Ownership - Interest Rate Distribuition", fontsize=20)
g1.set_xlabel("", fontsize=15)
g1.set_ylabel("Interest Rate", fontsize=15)

plt.subplots_adjust(hspace = 0.3,top = 0.9)

plt.show()

# %% [markdown]
# ## Crosstab - Home Ownership by Loan Status

# %%
loan_home = ['loan_status', 'home_ownership']
cm = sns.light_palette("green", as_cmap=True)
round(pd.crosstab(df_loan[loan_home[0]], df_loan[loan_home[1]], 
            normalize='index'),2).fillna(0).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col1 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col5 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_106eff82_ac3e_11ea_b500_0005165a0b35" ><thead>    <tr>        <th class="index_name level0" >home_ownership</th>        <th class="col_heading level0 col0" >ANY</th>        <th class="col_heading level0 col1" >MORTGAGE</th>        <th class="col_heading level0 col2" >NONE</th>        <th class="col_heading level0 col3" >OTHER</th>        <th class="col_heading level0 col4" >OWN</th>        <th class="col_heading level0 col5" >RENT</th>    </tr>    <tr>        <th class="index_name level0" >loan_status</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_106eff82_ac3e_11ea_b500_0005165a0b35level0_row0" class="row_heading level0 row0" >Charged Off</th>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col0" class="data row0 col0" >0.000000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col1" class="data row0 col1" >0.430000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col4" class="data row0 col4" >0.110000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row0_col5" class="data row0 col5" >0.460000</td>
#             </tr>
#             <tr>
#                         <th id="T_106eff82_ac3e_11ea_b500_0005165a0b35level0_row1" class="row_heading level0 row1" >Default</th>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col0" class="data row1 col0" >0.000000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col1" class="data row1 col1" >0.420000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col4" class="data row1 col4" >0.160000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row1_col5" class="data row1 col5" >0.420000</td>
#             </tr>
#             <tr>
#                         <th id="T_106eff82_ac3e_11ea_b500_0005165a0b35level0_row2" class="row_heading level0 row2" >Fully Paid</th>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col0" class="data row2 col0" >0.000000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col1" class="data row2 col1" >0.510000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col2" class="data row2 col2" >0.000000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col4" class="data row2 col4" >0.110000</td>
#                         <td id="T_106eff82_ac3e_11ea_b500_0005165a0b35row2_col5" class="data row2 col5" >0.380000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <h2> Looking the Purpose distribuition  </h2>

# %%
# Now will start exploring the Purpose variable
plt.figure(figsize = (14,13))

plt.subplot(211)
g = sns.violinplot(x="purpose",y="int_rate",data=df_loan,
                    hue="application_type", split=True)
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_title("Purposes - Interest Rate Distribution by Application Type", fontsize=20)
g.set_xlabel("Purpose Category's", fontsize=17)
g.set_ylabel("Interest Rate Distribution", fontsize=17)

plt.subplot(212)
g1 = sns.violinplot(x="purpose",y="loan_amnt",data=df_loan,
                    hue="application_type", split=True)
g1.set_xticklabels(g1.get_xticklabels(),rotation=45)
g1.set_title("Purposes - Loan Amount Distribution by Application Type", fontsize=20)
g1.set_xlabel("Purpose Category's", fontsize=17)
g1.set_ylabel("Loan Amount Distribution", fontsize=17)

plt.subplots_adjust(hspace = 0.5,top = 0.9)

plt.show()

# %% [markdown]
# <h2>Looking the Grades </h2>
# I will explore some variables.<br>
# the first variable I will explore is GRADE.<br>
# description of grade: <b>LC assigned loan grade</b>

# %%
order_sub = df_loan.groupby("sub_grade")['int_rate'].count().index

plt.figure(figsize=(14,16))

plt.suptitle('Grade and Sub-Grade Distributions \n# Interest Rate and Loan Amount #', fontsize=22)

plt.subplot(311)
g = sns.boxplot(x="grade", y="loan_amnt", data=df_loan,
                palette="hls", hue="application_type", 
                order=["A",'B','C','D','E','F', 'G'])
g.set_xlabel("Grade Values", fontsize=17)
g.set_ylabel("Loan Amount", fontsize=17)
g.set_title("Lending Club Loan - Loan Amount Distribution by Grade", fontsize=20)
g.legend(loc='upper right')

plt.subplot(312)
g1 = sns.boxplot(x='grade', y="int_rate",data=df_loan, 
               hue="application_type", palette = "hls",  
               order=["A",'B','C','D','E','F', 'G'])
g1.set_xlabel("Grade Values", fontsize=17)
g1.set_ylabel("Interest Rate", fontsize=17)
g1.set_title("Lending Club Loan - Interest Rate Distribution by Grade", fontsize=20)

plt.subplot(313)
g2 = sns.boxenplot(x="sub_grade", y="int_rate", data=df_loan, 
                   palette="hls", order=order_sub)
g2.set_xlabel("Sub Grade Values", fontsize=15)
g2.set_ylabel("Interest Rate", fontsize=15)
g2.set_title("Lending Club Loan - Interest Rate Distribution by Sub-Grade", fontsize=20)

plt.subplots_adjust(hspace = 0.4,top = 0.9)

plt.show()

# %% [markdown]
# Very interesting!!!! <br>
# We can clearly see different patterns between Individual and Joint applications.<br>
# In sub grade we can see a clearly correlation with interest rate.... Altought we can see many loans of "high" sub-grades with low interest rate <br>

# %% [markdown]
# ## Mean interest rate by all grades and sub-grades

# %%
loan_grade = ['sub_grade', 'grade']
cm = sns.light_palette("green", as_cmap=True)
round(pd.crosstab(df_loan[loan_grade[0]], df_loan[loan_grade[1]], 
            values=df_loan['int_rate'], aggfunc='mean'),2).fillna(0).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_1791b520_ac3e_11ea_b500_0005165a0b35row0_col0 {
#             background-color:  #4aa94a;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row0_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row0_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row0_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row1_col0 {
#             background-color:  #2f9a2f;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row1_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row1_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row2_col0 {
#             background-color:  #1e901e;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row2_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row2_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row3_col0 {
#             background-color:  #138a13;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row3_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row3_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row3_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row3_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row4_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row4_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row4_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row4_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row4_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row4_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row5_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row5_col1 {
#             background-color:  #3ba13b;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row5_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row5_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row5_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row5_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row5_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row6_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row6_col1 {
#             background-color:  #289628;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row6_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row6_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row6_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row6_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row6_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row7_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row7_col1 {
#             background-color:  #178d17;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row7_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row7_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row7_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row7_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row7_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row8_col1 {
#             background-color:  #098509;
#             color:  #f1f1f1;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row8_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_1791b520_ac3e_11ea_b500_0005165a0b35row8_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;

# %% [markdown]
# Very cool!! Now we can see that the difference of all subgrades of loans

# %% [markdown]
# # Employment Features

# %%
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import warnings
from collections import Counter
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#First plot
trace0 = go.Bar(
    x = df_loan.emp_title.value_counts()[:40].index.values,
    y = df_loan.emp_title.value_counts()[:40].values,
    marker=dict(
        color=df_loan.emp_title.value_counts()[:40].values
    ),
)

data = [trace0]

layout = go.Layout(
    yaxis=dict(
        title='Count'
    ),
    xaxis=dict(
        title='Employment name'
    ),
    title='TOP 40 Employment Title'
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='emp-title-bar')
# Out:
# <div>
#
#
#             <div id="7ef60e7b-c2eb-4799-84a2-7db0688e7a26" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7ef60e7b-c2eb-4799-84a2-7db0688e7a26")) {
#                     Plotly.newPlot(
#                         '7ef60e7b-c2eb-4799-84a2-7db0688e7a26',
#                         [{"marker": {"color": [20499, 18706, 9805, 8477, 8253, 8012, 7230, 7213, 6154, 5345, 5013, 4861, 4405, 4378, 4134, 3993, 3954, 3414, 3403, 3342, 3200, 2984, 2976, 2957, 2687, 2639, 2555, 2484, 2477, 2456, 2429, 2415, 2317, 2280, 2056, 2042, 1969, 1881, 1877, 1865]}, "type": "bar", "x": ["Teacher", "Manager", "Owner", "Registered Nurse", "RN", "Supervisor", "Driver", "Sales", "Project Manager", "Office Manager", "General Manager", "Director", "owner", "manager", "Engineer", "President", "teacher", "Vice President", "driver", "Operations Manager", "Accountant", "Administrative Assistant", "Sales Manager", "Attorney", "Account Manager", "Police Officer", "Nurse", "Technician", "Analyst", "sales", "Executive Assistant", "Truck Driver", "Store Manager", "supervisor", "Paralegal", "Software Engineer", "Server", "Controller", "Branch Manager", "truck driver"], "y": [20499, 18706, 9805, 8477, 8253, 8012, 7230, 7213, 6154, 5345, 5013, 4861, 4405, 4378, 4134, 3993, 3954, 3414, 3403, 3342, 3200, 2984, 2976, 2957, 2687, 2639, 2555, 2484, 2477, 2456, 2429, 2415, 2317, 2280, 2056, 2042, 1969, 1881, 1877, 1865]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scat ...

# %% [markdown]
# ## Grades by each Employer Title
# - I will consider only the 20 most common Employer Titles to see how the grades are distributed by different professionals

# %%
title_mask = df_loan.emp_title.value_counts()[:20].index.values 
cm = sns.light_palette("green", as_cmap=True)

round(pd.crosstab(df_loan[df_loan['emp_title'].isin(title_mask)]['emp_title'], 
                  df_loan[df_loan['emp_title'].isin(title_mask)]['sub_grade'], 
                  normalize='index') * 100,2).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col0 {
#             background-color:  #178c17;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col1 {
#             background-color:  #43a543;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col2 {
#             background-color:  #44a544;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col3 {
#             background-color:  #259425;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col4 {
#             background-color:  #41a441;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col5 {
#             background-color:  #44a644;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col6 {
#             background-color:  #9ed89e;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col7 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col8 {
#             background-color:  #4dab4d;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col9 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col10 {
#             background-color:  #59b159;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col11 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col12 {
#             background-color:  #85ca85;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col13 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col14 {
#             background-color:  #b1e2b1;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col15 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col16 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col17 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col18 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col19 {
#             background-color:  #bae7ba;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col20 {
#             background-color:  #abdfab;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col21 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col22 {
#             background-color:  #96d396;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col23 {
#             background-color:  #9dd79d;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col24 {
#             background-color:  #a2daa2;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col25 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col26 {
#             background-color:  #c0eac0;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col27 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col28 {
#             background-color:  #209220;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col29 {
#             background-color:  #4fac4f;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col30 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col31 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col32 {
#             background-color:  #7ac37a;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col33 {
#             background-color:  #99d599;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow0_col34 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col0 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col1 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col2 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col3 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col4 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col5 {
#             background-color:  #acdfac;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col6 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col7 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col8 {
#             background-color:  #5bb25b;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col9 {
#             background-color:  #289628;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col10 {
#             background-color:  #4caa4c;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col11 {
#             background-color:  #359d35;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col12 {
#             background-color:  #5bb25b;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col13 {
#             background-color:  #46a746;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col14 {
#             background-color:  #0e870e;
#             color:  #f1f1f1;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col15 {
#             background-color:  #329c32;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col16 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col17 {
#             background-color:  #0f880f;
#             color:  #f1f1f1;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col18 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col19 {
#             background-color:  #2e992e;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col20 {
#             background-color:  #289628;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col21 {
#             background-color:  #71bf71;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col22 {
#             background-color:  #7ac47a;
#             color:  #000000;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col23 {
#             background-color:  #098509;
#             color:  #f1f1f1;
#         }    #T_39d9ed16_cf60_11e9_82f9_8bad9f16ee8drow1_col24 {
#             background-color:  #

# %% [markdown]
# Very cool!!! We can see that Director, Engineer, President, Vice President are the category's with highest incidence in Grade A; <br>
# Analyzing this table we can get some insights about the profile of grades and professionals.

# %% [markdown]
# <h2>Title</h2>

# %%
#First plot
trace0 = go.Bar(
    x = df_loan.title.value_counts()[:40].index.values,
    y = df_loan.title.value_counts()[:40].values,
    marker=dict(
        color=df_loan.title.value_counts()[:40].values
    ),
)

data = [trace0]

layout = go.Layout(
    yaxis=dict(
        title='Count'
    ),
    xaxis=dict(
        title='Employment name'
    ),
    title='TOP 40 Employment Title'
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='emp-title-bar')
# Out:
# <div>
#
#
#             <div id="5deeedfe-9053-43f7-b19f-f25f8d4c7f63" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5deeedfe-9053-43f7-b19f-f25f8d4c7f63")) {
#                     Plotly.newPlot(
#                         '5deeedfe-9053-43f7-b19f-f25f8d4c7f63',
#                         [{"marker": {"color": [638964, 240683, 72127, 63878, 22974, 15692, 13061, 11359, 10769, 7721, 7647, 5611, 5353, 4812, 3777, 2347, 2163, 2086, 1770, 1757, 1464, 1377, 1254, 1163, 1028, 802, 779, 756, 748, 719, 714, 704, 670, 666, 650, 634, 594, 593, 584, 584]}, "type": "bar", "x": ["Debt consolidation", "Credit card refinancing", "Home improvement", "Other", "Major purchase", "Debt Consolidation", "Medical expenses", "Business", "Car financing", "Vacation", "Moving and relocation", "Home buying", "Consolidation", "debt consolidation", "Debt Consolidation Loan", "Credit Card Consolidation", "consolidation", "Personal Loan", "Consolidation Loan", "Home Improvement", "Credit Card Refinance", "Credit Card Payoff", "Consolidate", "Personal", "Loan", "Freedom", "Credit Card Loan", "consolidate", "personal", "Debt", "personal loan", "Green loan", "home improvement", "Payoff", "Credit Cards", "payoff", "DEBT CONSOLIDATION", "Debt Consolidation ", "Credit Card", "Home Improvement Loan"], "y": [638964, 240683, 72127, 63878, 22974, 15692, 13061, 11359, 10769, 7721, 7647, 5611, 5353, 4812, 3777, 2347, 2163, 2086, 1770, 1757, 1464, 1377, 1254, 1163, 1028, 802, 779, 756, 748, 719, 714, 704, 670, 666, 650, 634, 594, 593, 584, 584]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scat ...

# %% [markdown]
# <h2>Emp lenght crossed by some columns</h2>

# %% [markdown]
# ## Emp Length Graphics

# %%
# emp_lenght description: 
# Employment length in years. Possible values are between 0 and 10 where 0 means 
# less than one year and 10 means ten or more years. 

emp_ord = ['< 1 year', '1 year', '2 years', '3 years',
           '4 years', '5 years', '6 years', '7 years',
           '8 years', '9 years', '10+ years']

fig, ax = plt.subplots(2,1, figsize=(14,11))
g = sns.boxplot(x="emp_length", y="int_rate", data=df_loan,
                ax=ax[0], color='blue',
                order=emp_ord)

z = sns.violinplot(x="emp_length", y="loan_amnt",data=df_loan, 
                   ax=ax[1], color='blue',
                   order=emp_ord)
               
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Interesting! We can see that the years do not influence the interest rate but it have a slightly difference considering the loan_amount patterns

# %% [markdown]
# ### Let's confirm the mean of int rate of Employment Length

# %%
# Emp Length interest rate mean
df_loan.groupby(["emp_length"])['int_rate'].mean().reset_index().T
# Out:
#                   0          1        2        3        4        5        6  \
# emp_length   1 year  10+ years  2 years  3 years  4 years  5 years  6 years
# int_rate    13.2905    13.2082  13.2652  13.2401  13.2763  13.2922  13.3667
#
#                   7        8        9        10
# emp_length  7 years  8 years  9 years  < 1 year
# int_rate    13.3762   13.219  13.2589   13.2213

# %% [markdown]
# We can note that it's really a very similar mean by all emp length.

# %% [markdown]
# <h2>Terms column</h2>

# %%
order_sub = df_loan.groupby("sub_grade")['int_rate'].count().index

plt.figure(figsize=(14,18))

plt.suptitle('Term Distributions \n# Count, Interest Rate and Loan Amount #', fontsize=22)

plt.subplot(311)
g = sns.countplot(x="term", data=df_loan,color='blue')
g.set_xlabel("Term Values", fontsize=17)
g.set_ylabel("Count", fontsize=17)
g.set_title("Lending Club Loan \nTerm Count Distribution", fontsize=20)
sizes=[]
for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=14) 
g.set_ylim(0, max(sizes) * 1.10)

plt.subplot(312)
g1 = sns.violinplot(x='term', y="int_rate",data=df_loan )
g1.set_xlabel("Term Values", fontsize=17)
g1.set_ylabel("Interest Rate", fontsize=17)
g1.set_title("Lending Club Loan \nInterest Rate Distribution by Term Values", fontsize=20)

plt.subplot(313)
g2 = sns.violinplot(x="term", y="loan_amnt", data=df_loan)
g2.set_xlabel("Term Values", fontsize=17)
g2.set_ylabel("Loan Amount", fontsize=17)
g2.set_title("Lending Club Loan \nLoan Amount Distribution by Term Values", fontsize=20)

plt.subplots_adjust(hspace = 0.4, top = 0.9)

plt.show()

# %% [markdown]
# <h2>Looking the heatmap cross tab of Adress State x Loan Status<h2>

# %%
#Exploring the State Adress x Loan Status
adress_loan = ['addr_state', 'loan_status']
cm = sns.light_palette("green", as_cmap=True)
round(pd.crosstab(df_loan[adress_loan[0]], 
                  df_loan[adress_loan[1]], 
                  normalize='all')*100,2).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow0_col0 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow0_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow1_col0 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow1_col2 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow2_col0 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow2_col2 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow3_col0 {
#             background-color:  #c0eac0;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow3_col2 {
#             background-color:  #c0eac0;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow4_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow4_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow5_col0 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow5_col2 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow6_col0 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow6_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow6_col2 {
#             background-color:  #cef2ce;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow7_col0 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow7_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow7_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow8_col0 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow8_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow8_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow9_col0 {
#             background-color:  #6cbc6c;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow9_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow9_col2 {
#             background-color:  #79c379;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow10_col0 {
#             background-color:  #b7e5b7;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow10_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow10_col2 {
#             background-color:  #b2e3b2;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow11_col0 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow11_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow11_col2 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow12_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow12_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow12_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow13_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow13_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow13_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow14_col0 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow14_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow14_col2 {
#             background-color:  #a8dda8;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow15_col0 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow15_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow15_col2 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow16_col0 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow16_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow16_col2 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow17_col0 {
#             background-color:  #d6f7d6;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow17_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow17_col2 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow18_col0 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow18_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow18_col2 {
#             background-color:  #d4f6d4;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow19_col0 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow19_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_442404c8_cf60_11e9_82f9_8bad9f16ee8drow19_col2 {
#             background-color:  #c2ebc2;

# %% [markdown]
# Cool, we can see that the below states have the highest shares of loans:
# - CA
# - FL
# - NY
# - Texas

# %%
cols = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
        'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length',
        'home_ownership', 'desc', 'purpose', 'total_pymnt', 'total_pymnt_inv',]

# %%
df_loan['settlement_status'].fillna("None", inplace=True)

# %%
plt.figure(figsize=(16,18))

plt.subplot(311)
g = sns.countplot(x='settlement_status', data=df_loan, color='blue')
g.set_title('Settlement Status Distribution', fontsize=21)
g.set_ylabel("Count", fontsize=17)
g.set_xlabel("Settlement Status", fontsize=17)

sizes=[]
for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=14) 
g.set_ylim(0, max(sizes) * 1.10)

plt.subplot(312)
g1 = sns.violinplot(x='settlement_status', y="int_rate",
                    data=df_loan, color='blue') 
g1.set_xlabel("Settlement Status", fontsize=17)
g1.set_ylabel("Interest Rate", fontsize=17)
g1.set_title("Interest Rate Distribution by Settlement Status", 
             fontsize=20)

plt.subplot(313)
g2 = sns.violinplot(x="settlement_status", y="loan_amnt", 
                    data=df_loan, color='blue')
g2.set_xlabel("Settlement Status", fontsize=17)
g2.set_ylabel("Loan Amount", fontsize=17)
g2.set_title("Loan Amount Distribution by Settlement Status", 
             fontsize=20)

plt.subplots_adjust(hspace = 0.4, top = 0.9)

plt.show()

# %%
df_loan['loan_value'] = (100 * df_loan.revol_bal) / df_loan['revol_util']

# %% [markdown]
# # Delinq 2 years
# - The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years

# %%
round(pd.crosstab(df_loan['delinq_2yrs'],df_loan['loan_status'],   normalize='columns') * 100,2)[:15]
# Out:
# loan_status  Charged Off  Default  Fully Paid
# delinq_2yrs
# 0.0                79.26    67.74       81.11
# 1.0                13.38    19.35       12.66
# 2.0                 4.18     3.23        3.64
# 3.0                 1.58     6.45        1.31
# 4.0                 0.71     0.00        0.58
# 5.0                 0.37     3.23        0.30
# 6.0                 0.19     0.00        0.16
# 7.0                 0.12     0.00        0.09
# 8.0                 0.06     0.00        0.05
# 9.0                 0.04     0.00        0.03
# 10.0                0.03     0.00        0.02
# 11.0                0.02     0.00        0.01
# 12.0                0.02     0.00        0.01
# 13.0                0.01     0.00        0.01
# 14.0                0.01     0.00        0.01
# 15.0                0.00     0.00        0.00

# %% [markdown]
# # DTI
# - A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.

# %%
cm = sns.light_palette("green", as_cmap=True)

round((pd.crosstab(df_loan['loan_status'], df_loan['purpose'],
            values=df_loan['dti'], aggfunc='mean')).fillna(0),
      2).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col0 {
#             background-color:  #c9efc9;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col2 {
#             background-color:  #7ac37a;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col3 {
#             background-color:  #048204;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col7 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col8 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col9 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col10 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col11 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col12 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col13 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col1 {
#             background-color:  #1e901e;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col8 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col10 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col12 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow1_col13 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col4 {
#             background-color:  #59b159;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col5 {
#             background-color:  #259425;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col6 {
#             background-color:  #1b8f1b;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col7 {
#             background-color:  #64b764;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col9 {
#             background-color:  #62b662;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col10 {
#             background-color:  #118911;
#             color:  #f1f1f1;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col11 {
#             background-color:  #188d18;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col12 {
#             background-color:  #168c16;
#             color:  #000000;
#         }    #T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow2_col13 {
#             background-color:  #148b14;
#             color:  #000000;
#         }</style><table id="T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8d" ><thead>    <tr>        <th class="index_name level0" >purpose</th>        <th class="col_heading level0 col0" >car</th>        <th class="col_heading level0 col1" >credit_card</th>        <th class="col_heading level0 col2" >debt_consolidation</th>        <th class="col_heading level0 col3" >educational</th>        <th class="col_heading level0 col4" >home_improvement</th>        <th class="col_heading level0 col5" >house</th>        <th class="col_heading level0 col6" >major_purchase</th>        <th class="col_heading level0 col7" >medical</th>        <th class="col_heading level0 col8" >moving</th>        <th class="col_heading level0 col9" >other</th>        <th class="col_heading level0 col10" >renewable_energy</th>        <th class="col_heading level0 col11" >small_business</th>        <th class="col_heading level0 col12" >vacation</th>        <th class="col_heading level0 col13" >wedding</th>    </tr>    <tr>        <th class="index_name level0" >loan_status</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8dlevel0_row0" class="row_heading level0 row0" >Charged Off</th>
#                         <td id="T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col0" class="data row0 col0" >17.49</td>
#                         <td id="T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col1" class="data row0 col1" >20.51</td>
#                         <td id="T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col2" class="data row0 col2" >20.81</td>
#                         <td id="T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col3" class="data row0 col3" >11.05</td>
#                         <td id="T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col4" class="data row0 col4" >17.76</td>
#                         <td id="T_4aa7401c_cf60_11e9_82f9_8bad9f16ee8drow0_col5" class="data row0 col5" >16.72</td>

# %% [markdown]
# # Mean of Credit Utilization Rate by Loan Status and Purpose.
#
# revol_util: Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.

# %%
cm = sns.light_palette("green", as_cmap=True)

round((pd.crosstab(df_loan['loan_status'], df_loan['purpose'],
            values=df_loan['revol_util'], aggfunc='mean')).fillna(0),
      2).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col1 {
#             background-color:  #bbe8bb;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col2 {
#             background-color:  #46a746;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col7 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col8 {
#             background-color:  #c4edc4;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col9 {
#             background-color:  #aadeaa;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col10 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col11 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col12 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col13 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col7 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col8 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col9 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col10 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col11 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col12 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow1_col13 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col0 {
#             background-color:  #4eab4e;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col3 {
#             background-color:  #2c982c;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col4 {
#             background-color:  #2e992e;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col5 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col6 {
#             background-color:  #138a13;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col10 {
#             background-color:  #1b8f1b;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col11 {
#             background-color:  #168c16;
#             color:  #000000;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col12 {
#             background-color:  #098509;
#             color:  #f1f1f1;
#         }    #T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow2_col13 {
#             background-color:  #168c16;
#             color:  #000000;
#         }</style><table id="T_4ad02662_cf60_11e9_82f9_8bad9f16ee8d" ><thead>    <tr>        <th class="index_name level0" >purpose</th>        <th class="col_heading level0 col0" >car</th>        <th class="col_heading level0 col1" >credit_card</th>        <th class="col_heading level0 col2" >debt_consolidation</th>        <th class="col_heading level0 col3" >educational</th>        <th class="col_heading level0 col4" >home_improvement</th>        <th class="col_heading level0 col5" >house</th>        <th class="col_heading level0 col6" >major_purchase</th>        <th class="col_heading level0 col7" >medical</th>        <th class="col_heading level0 col8" >moving</th>        <th class="col_heading level0 col9" >other</th>        <th class="col_heading level0 col10" >renewable_energy</th>        <th class="col_heading level0 col11" >small_business</th>        <th class="col_heading level0 col12" >vacation</th>        <th class="col_heading level0 col13" >wedding</th>    </tr>    <tr>        <th class="index_name level0" >loan_status</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ad02662_cf60_11e9_82f9_8bad9f16ee8dlevel0_row0" class="row_heading level0 row0" >Charged Off</th>
#                         <td id="T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col0" class="data row0 col0" >46.57</td>
#                         <td id="T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col1" class="data row0 col1" >59.03</td>
#                         <td id="T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col2" class="data row0 col2" >56.07</td>
#                         <td id="T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col3" class="data row0 col3" >46.12</td>
#                         <td id="T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col4" class="data row0 col4" >46.74</td>
#                         <td id="T_4ad02662_cf60_11e9_82f9_8bad9f16ee8drow0_col5" class="data row0 col5" >42.66</td>

# %%
resumetable(df_loan.reset_index())[:45]
# Out:
# Dataset Shape: (1303638, 150)
#                       Name   dtypes  Missing  Uniques         First Value  \
# 0                    index    int64        0  1303638                 100
# 1                       id  float64  1303638        0                 NaN
# 2                member_id  float64  1303638        0                 NaN
# 3                loan_amnt    int64        0     1553               30000
# 4              funded_amnt    int64        0     1553               30000
# 5          funded_amnt_inv  float64        0     9014               30000
# 6                     term   object        0        2           36 months
# 7                 int_rate  float64        0      654               22.35
# 8              installment  float64        0    82574             1151.16
# 9                    grade   object        0        7                   D
# 10               sub_grade   object        0       35                  D5
# 11               emp_title   object    82582   371436         Supervisor
# 12              emp_length   object    75457       11             5 years
# 13          home_ownership   object        0        6            MORTGAGE
# 14              annual_inc  float64        0    62989              100000
# 15     verification_status   object        0        3     Source Verified
# 16                 issue_d   object        0      139            Dec-2018
# 17             loan_status   object        0        3          Fully Paid
# 18              pymnt_plan   object        0        1                   n
# 19                     url  float64  1303638        0                 NaN
# 20                    desc   object  1180311   121809                 NaN
# 21                 purpose   object        0       14  debt_consolidation
# 22                   title   object    15426    61678  Debt consolidation
# 23                zip_code   object        1      943               917xx
# 24              addr_state   object        0       51                  CA
# 25                     dti  float64      312     6870               30.46
# 26             delinq_2yrs  float64        0       30                   0
# 27        earliest_cr_line   object        0      738            Jan-2012
# 28          inq_last_6mths  float64        1        9                   0
# 29  mths_since_last_delinq  float64   657833      163                  51
# 30  mths_since_last_record  float64  1081865      124                  84
# 31                open_acc  float64        0       84                  11
# 32                 pub_rec  float64        0       37                   1
# 33               revol_bal    int64        0    82819               15603
# 34              revol_util  float64      810     1363                  37
# 35               total_acc  float64        0      142                  19
# 36     initial_list_status   object        0        2                   w
# 37               out_prncp  float64        0       32                   0
# 38           out_prncp_inv  float64        0       32                   0
# 39             total_pymnt  float64        0  1224348             30026.4
# 40         total_pymnt_inv  float64        0   987066             30026.4
# 41         total_rec_prncp  float64        0   200281               30000
# 42           total_rec_int  float64        0   508635               26.44
# 43      total_rec_late_fee  float64        0    15516                   0
# 44              recoveries  float64        0   127607                   0
#
#                             Second Value              Third Value  Entropy
# 0                                    152                      170    20.31
# 1                                    NaN                      NaN     0.00
# 2                                    NaN                      NaN     0.00
# 3                                  40000                    20000     6.96
# 4                                  40000                    20000     6.96
# 5                                  40000                    20000     7.41
# 6                              60 months                36 months     0.80
# 7                                  16.14                     7.56     7.52
# 8                                 975.71                   622.68    14.02
# 9                                      C                        A     2.33
# 10                                    C4                       A3     4.64
# 11  Assistant to the Treasurer (Payroll)                  Teacher    14.86
# 12                              < 1 year                10+ years     3.06
# 13                              MORTGAGE                 MORTGAGE     1.38
# 14                                 45000                   100000     8.30
# 15                              Verified             Not Verified     1.58
# 16                              Dec-2018                 Dec-2018     6.22
# 17                            Fully Paid               Fully Paid     0.72
# 18                                     n                        n     0.00
# 19                                   NaN                      NaN     0.00
# 20                                   NaN                      NaN    16.87
# 21                           credit_card              credit_card     1.93
# 22               Credit card refinancing  Credit card refinancing     4.01
# 23                                 456xx                    982xx     8.89
# 24                                    OH                       WA     4.82
# 25                                 50.53                    18.92    11.74
# 26                                     0                        0     1.01
# 27                              Jun-2009                 Feb-1999     8.42
# 28                                     0                        0     1.60
# 29                                   NaN                       48     6.30
# 30                                   NaN                      NaN     6.69
# 31                                    18                        9     4.34
# 32                                     0                        0     0.81
# 33                                 34971                    25416    15.21
# 34                                  64.5                     29.9     9.88
# 35                                    37                       19     5.52
# 36                                     w                        w     0.98
# 37                                     0                        0     0.00
# 38                                     0                        0     0.00
# 39                               40856.7                  20215.8    20.14
# 40                               40856.7                  20215.8    19.61
# 41                                 40000                    20000     9.71
# 42                                856.68                   215.79    18.43
# 43                                     0                        0     0.72
# 44                                     0                        0     2.81

# %% [markdown]
# # I'm improving this kernel, so stay Tuned and upvote if you liked =)

# %%
df_loan.select_dtypes(include=[int, float]).head()
# Out:
#      id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# 100 NaN        NaN      30000        30000          30000.0     22.35
# 152 NaN        NaN      40000        40000          40000.0     16.14
# 170 NaN        NaN      20000        20000          20000.0      7.56
# 186 NaN        NaN       4500         4500           4500.0     11.31
# 215 NaN        NaN       8425         8425           8425.0     27.27
#
#      installment  annual_inc  url    dti  ...  hardship_length  hardship_dpd  \
# 100      1151.16    100000.0  NaN  30.46  ...              NaN           NaN
# 152       975.71     45000.0  NaN  50.53  ...              NaN           NaN
# 170       622.68    100000.0  NaN  18.92  ...              NaN           NaN
# 186       147.99     38500.0  NaN   4.64  ...              NaN           NaN
# 215       345.18    450000.0  NaN  12.37  ...              NaN           NaN
#
#      orig_projected_additional_accrued_interest  \
# 100                                         NaN
# 152                                         NaN
# 170                                         NaN
# 186                                         NaN
# 215                                         NaN
#
#      hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 100                             NaN                           NaN
# 152                             NaN                           NaN
# 170                             NaN                           NaN
# 186                             NaN                           NaN
# 215                             NaN                           NaN
#
#      settlement_amount  settlement_percentage  settlement_term  int_round  \
# 100                NaN                    NaN              NaN         22
# 152                NaN                    NaN              NaN         16
# 170                NaN                    NaN              NaN          8
# 186                NaN                    NaN              NaN         11
# 215                NaN                    NaN              NaN         27
#
#        loan_value
# 100  42170.270270
# 152  54218.604651
# 170  85003.344482
# 186  29228.758170
# 215  56030.441400
#
# [5 rows x 111 columns]

# %%
numericals_clusters = ['loan_amnt', 'annual_inc', 'dti', 'total_acc', 'loan_status',
                       'revol_bal', 'revol_util', 'installment', 'int_rate']

# %%
resumetable(df_loan[numericals_clusters].reset_index())
# Out:
# Dataset Shape: (1303638, 10)
#           Name   dtypes  Missing  Uniques First Value Second Value  \
# 0        index    int64        0  1303638         100          152
# 1    loan_amnt    int64        0     1553       30000        40000
# 2   annual_inc  float64        0    62989      100000        45000
# 3          dti  float64      312     6870       30.46        50.53
# 4    total_acc  float64        0      142          19           37
# 5  loan_status   object        0        3  Fully Paid   Fully Paid
# 6    revol_bal    int64        0    82819       15603        34971
# 7   revol_util  float64      810     1363          37         64.5
# 8  installment  float64        0    82574     1151.16       975.71
# 9     int_rate  float64        0      654       22.35        16.14
#
#   Third Value  Entropy
# 0         170    20.31
# 1       20000     6.96
# 2      100000     8.30
# 3       18.92    11.74
# 4          19     5.52
# 5  Fully Paid     0.72
# 6       25416    15.21
# 7        29.9     9.88
# 8      622.68    14.02
# 9        7.56     7.52

# %%
df_loan[df_loan['dti'].isna()][numericals_clusters].nunique()
# Out:
# loan_amnt      109
# annual_inc       3
# dti              0
# total_acc       46
# loan_status      2
# revol_bal      306
# revol_util     264
# installment    298
# int_rate       102
# dtype: int64

# %%
df_loan[df_loan['dti'] == -1][numericals_clusters]
# Out:
#          loan_amnt  annual_inc  dti  total_acc loan_status  revol_bal  \
# 723428       15000     94000.0 -1.0       24.0  Fully Paid      15445
# 1377778      17000     75000.0 -1.0       34.0  Fully Paid      44587
#
#          revol_util  installment  int_rate
# 723428         45.8       482.25      9.75
# 1377778        78.2       391.08     13.49

# %%
df_loan['dti'].value_counts()[df_loan['dti'].value_counts() == 312]
# Out:
# 26.42    312
# 27.28    312
# 26.15    312
# 7.22     312
# Name: dti, dtype: int64
